# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Краткое-описание-проекта" data-toc-modified-id="Краткое-описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Краткое описание проекта</a></span><ul class="toc-item"><li><span><a href="#Цели-выполнения-проекта---узнать:" data-toc-modified-id="Цели-выполнения-проекта---узнать:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Цели выполнения проекта - узнать:</a></span></li><li><span><a href="#Общая-информация-о-предоставленных-данных" data-toc-modified-id="Общая-информация-о-предоставленных-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Общая информация о предоставленных данных</a></span></li></ul></li><li><span><a href="#Загрузим-данные-и-подготовим-их-к-анализу" data-toc-modified-id="Загрузим-данные-и-подготовим-их-к-анализу-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузим данные и подготовим их к анализу</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Зададим-функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Зададим-функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Зададим функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Проанализируем-общую-окупаемость-рекламы" data-toc-modified-id="Проанализируем-общую-окупаемость-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проанализируем общую окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-устройствам-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Посчитаем-и-визализируем-конверсию-в-разных-разрезах" data-toc-modified-id="Посчитаем-и-визализируем-конверсию-в-разных-разрезах-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Посчитаем и визализируем конверсию в разных разрезах</a></span></li><li><span><a href="#Посчитаем-и-визализируем-удержание-пользователей-в-разных-разрезах" data-toc-modified-id="Посчитаем-и-визализируем-удержание-пользователей-в-разных-разрезах-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Посчитаем и визализируем удержание пользователей в разных разрезах</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# ## Краткое описание проекта

# %% [markdown]
# Несмотря на огромные вложения в рекламу, последние несколько месяцев приложение Procrastinate Pro+ терпит убытки. Наша задача — разобраться в причинах и помочь компании выйти в плюс.
# Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# - лог сервера с данными об их посещениях,
# - выгрузка их покупок за этот период,
# - рекламные расходы.
#
# ### Цели выполнения проекта - узнать:
#
# - откуда приходят пользователи и какими устройствами они пользуются,
# - сколько стоит привлечение пользователей из различных рекламных каналов;
# - сколько денег приносит каждый клиент,
# - когда расходы на привлечение клиента окупаются,
# - какие факторы мешают привлечению клиентов.
#
# ### Общая информация о предоставленных данных
# Согласно предоставленной документации:
#
# Датасет `visits` хранит информацию о посещениях с сайта и включает в себя:
# - user_id — уникальный идентификатор пользователя
# - region — страна пользователя
# - device — тип устройства пользователя
# - channel — идентификатор источника перехода
# - session start — дата и время начала сессии
# - session end — дата и время окончания сессии
#
# Датасет `orders` хранит информацию о покупках и включает в себя:
# - user_id — уникальный идентификатор пользователя
# - event_dt — дата и время покупки
# - revenue — сумма заказа
#
# Датасет `costs` хранит информацию о раскходах на рекламу и включает в себя:
# - channel — идентификатор рекламного источника,
# - dt — дата проведения рекламной кампании,
# - costs — расходы на эту кампанию.

# %% [markdown]
# ##  Загрузим данные и подготовим их к анализу

# %% [markdown]
# Импортируем основные библиотеки для осуществления анализа

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# Загрузим данные о визитах, заказах и расходах в соответсвующие переменные

# %%
visits = pd.read_csv('visits_info_short.csv')
orders = pd.read_csv('orders_info_short.csv')
costs = pd.read_csv('costs_info_short.csv')

# %% [markdown]
# Выведим на экран полученные датасеты

# %%
display(visits.head())
display(orders.head())
costs.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# ...

# %% [markdown]
# Столбцы всех датасетов приведём к нижему регистру

# %%
datasets = [visits, orders, costs]
for dataset in datasets:
    dataset.columns = dataset.columns.str.lower()

# %% [markdown]
# Для того, чтобы убедиться в корректности данных, рассмотрим каждый датасет по отдельности.

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session start  309901 non-null  object
#  5   session end    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %% [markdown]
# Столбцы `user id`, `session Start` и `session End` переименуем.
# В столбцах, в которых отражены начало и конец сессии, поменяем тип данных на `datetime`

# %%
visits = visits.rename(columns = {'session start' : 'session_start', 'session end':'session_end', 'user id' : 'user_id'})
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])

# %% [markdown]
# Проверим получившийся результат

# %%
display(visits.head())
visits.info()
# Out:
#         user_id         region   device  channel       session_start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic 2019-05-01 03:33:35
#
#           session_end
# 0 2019-05-01 02:45:01
# 1 2019-05-01 04:47:35
# 2 2019-05-01 15:32:08
# 3 2019-05-01 00:54:25
# 4 2019-05-01 03:57:40
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
# ...

# %% [markdown]
# Проверим на наличие дубликатов

# %%
visits.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Рассммотри датасет `orders`

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user id   40212 non-null  int64
#  1   event dt  40212 non-null  object
#  2   revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %% [markdown]
# Переименуем столбцы `event dt` и `user id`. В столбце `event_dt` поменяем тип данных на `datetime`

# %%
orders = orders.rename(columns = {'user id' : 'user_id', 'event dt' : 'event_dt'})
orders['event_dt'] = pd.to_datetime(orders['event_dt'])

# %%
display(orders.head())
orders.info()
# Out:
#         user_id            event_dt  revenue
# 0  188246423999 2019-05-01 23:09:52     4.99
# 1  174361394180 2019-05-01 12:24:04     4.99
# 2  529610067795 2019-05-01 11:34:04     4.99
# 3  319939546352 2019-05-01 15:34:40     4.99
# 4  366000285810 2019-05-01 13:59:51     4.99
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %% [markdown]
# Проверим на наличие дубликатов

# %%
orders.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Рассмотрим датасет `costs`

# %%
display(costs.head())
costs.info()
# Out:
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Приведём столбец `dt` к типу данных `datetime`

# %%
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# Проверим получившийся результат

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
costs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Вывод

# %% [markdown]
# На старте исследования причин убытков приложения были выгружены и приведены к корректному виду датасеты `visits`, `orders` и `costs`

# %% [markdown]
# <div class="alert alert-info>
#
#   <b>Комментарий студента</b>
#
#   Спасибо, учту!
#
# </div>

# %% [markdown]
# ## Зададим функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# Зададим функцию `get_profiles()`, которая будет определять пользовательские профили на основе имеющихся данных

# %%
def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# Задаим функцию `get_retention()`, которая расчитывает удержание пользователей

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Зададим функцию `get_convesrion()` для расчёта конверсии

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Зададим функцию `get_ltv()` для расчёта LTV и ROI

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# Зададим фунцкию `filter_data()` сглаживания фрейма

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# Зададим функцию `plot_retention()` для визаулизации удержания

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Функция для визуализации конверсии `plot_conversion()`

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Функция `plot_ltv_roi()` для визуализации LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Построим профили пользователей и выведим на экран

# %%
profile = get_profiles(visits, orders, costs)
profile
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %% [markdown]
# Определим минимальную и максимальную дату привлечения пользователей

# %%
display(profile['dt'].min())
profile['dt'].max()
# Out:
# datetime.date(2019, 5, 1)
# datetime.date(2019, 10, 27)

# %% [markdown]
# Можно заключить, что данные представленные в датасете лежат во временных рамках начиная с 1 мая и по 27 октября 2019 года

# %% [markdown]
# Определим из каких стран, с каких устройств и с каких источников привлечения пользователи приходят в приложение.
#
# В результате получим три столбца:
#
# - `total_amount_users` - информация об общем количестве пользователей
# - `total_paying_of_users` - информация только о платящих пользователях
# - `percent_of_paying_users` - доля платящих пользователей из общего числа

# %%
parametrs_of_users = ['region','device','channel'] 

for parametr in parametrs_of_users:
    users_region = profile.groupby(parametr).agg({'user_id' : 'nunique'}).rename(columns = {'user_id' : 'total_amount_users'}) \
    .merge(profile.query('payer == True').groupby(parametr) \
    .agg({'user_id' : 'nunique'}).rename(columns = {'user_id' : 'total_paying_of_users'}), on = parametr, how ='inner')

    users_region['percent_of_paying_users, %'] = round((users_region['total_paying_of_users']
                                                     /users_region['total_amount_users'])*100,2)
    print('Таблица, отражающая количество пользователей и долю платящих для каждого', parametr)
    display(users_region.sort_values(by = 'percent_of_paying_users, %', ascending=False))
    print()
# Out:
# Таблица, отражающая количество пользователей и долю платящих для каждого region
#                total_amount_users  total_paying_of_users  \
# region
# United States              100002                   6902
# Germany                     14981                    616
# UK                          17575                    700
# France                      17450                    663
#
#                percent_of_paying_users, %
# region
# United States                        6.90
# Germany                              4.11
# UK                                   3.98
# France                               3.80
# Таблица, отражающая количество пользователей и долю платящих для каждого device
#          total_amount_users  total_paying_of_users  percent_of_paying_users, %
# device
# Mac                   30042                   1912                        6.36
# iPhone                54479                   3382                        6.21
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Пользователи 4-ёх стран пользуются приложением - Франция, Германия, Великобритания, США. Можем заметить, что наибольшее число пользователей находится в США и доля платящих пользователей у Америки - максимальное, по сравнению с другими странами
#
#
# - Пользователи 4-ёх устройств пользуются приложением. Наибольшее число пользователей используют Iphone, но доля платящих пользователей с устройством Mac незначительно больше, чем у Iphone
#
#
# - Всего используется 11 каналов для привлечения пользователей, наибольшее значение доли платящих пользователей занимает канал `FaceBoom`. Хотя, стоит заметить, что в большинстве случаев пользователи скачивают приложение через органические источники.

# %% [markdown]
# ## Маркетинг
#
# Выясните:
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %% [markdown]
# Посчитаем общую сумму расходов на маркетинг. Выведим датасет на экран

# %%
profile_without_organic = profile.query('channel != "organic"')
print('Общая сумма расходов на маркетинг составляет', profile_without_organic['acquisition_cost'].sum())
profile.head()
# Out:
# Общая сумма расходов на маркетинг составляет 105497.3
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# Общая сумма расходов на маркетинг составляет 105497 рублей.
#
# Выясним сумму расходов на маркетинг по каналам привлечения и по времени

# %%
plt.figure(figsize=(20, 10))

ax1 = plt.subplot(1,2,1)

profile_without_organic.groupby(['channel']).agg({'acquisition_cost' : 'sum'}).plot(kind='bar',grid=True, ax=ax1)
plt.title('Сумма расходов на маркетинг по каналам привлечения')
plt.xlabel('Каналы привлечения пользователей')
plt.legend()

ax2= plt.subplot(1,2,2)

profile_without_organic.groupby(['dt']).agg({'acquisition_cost' : 'sum'}).plot(grid=True,ax=ax2);
plt.title('Сумма расходов на маркетинг по времени')
plt.xlabel('Время')
plt.subplot(1,2,2)

plt.show()

# %% [markdown]
# Можем сделать промежуточные выводы:
#
# - Максимальная сумма расходов на маркетинг приходится на канал `TipTop`
# - Сумма расходов на маркетинг растёт с течением времени

# %% [markdown]
# Узнаем сколько в среднем стоило привлечение одного пользователя из каждого источника

# %%
average_cost = profile_without_organic.groupby('channel').agg({'user_id' : 'nunique', 'acquisition_cost' : 'sum'}). \
rename(columns = {'user_id' : 'unique_user'})

average_cost['average_cost_per_user'] = average_cost['acquisition_cost']/average_cost['unique_user']
average_cost.sort_values(by = 'average_cost_per_user', ascending=False)
# Out:
#                     unique_user  acquisition_cost  average_cost_per_user
# channel
# TipTop                    19561          54751.30               2.799003
# FaceBoom                  29144          32445.60               1.113286
# AdNonSense                 3880           3911.25               1.008054
# lambdaMediaAds             2149           1557.60               0.724802
# WahooNetBanner             8553           5151.00               0.602245
# RocketSuperAds             4448           1833.00               0.412095
# OppleCreativeMedia         8605           2151.25               0.250000
# YRabbit                    4312            944.22               0.218975
# MediaTornado               4364            954.48               0.218717
# LeapBob                    8553           1797.60               0.210172

# %% [markdown]
# Так же рассчитаем средний CAC на одного пользователя для всего проекта

# %%
average_cost['acquisition_cost'].sum()/average_cost['unique_user'].sum()
# Out:
# 1.127481323942759

# %% [markdown]
# ### Вывод

# %% [markdown]
# В ходе исследования затрат на маркетинг были выявлены следующие особенности:
#
# - Общая сумма расходов на маркетинг составляет 105497 единиц
# - Максимальная сумма расходов на маркетинг приходится на канал `TipTop`
# - Сумма расходов на маркетинг растёт с течением времени
# - Максимальная стоимость на привлечение одного пользователя наблюдается так же в канале `TipTop`
# - Средний CAC на одного пользователя для всего проекта составляет приблизительно 1.12 единиц

# %% [markdown]
# ## Проанализируем общую окупаемость рекламы

# %% [markdown]
# Проанализируем общую окупаемость рекламы, используем функции `get_ltv()` и `plot_ltv_roi()`.
#
# Так же необходимо ввести две переменные: момент анализа и горизон анализа.
#
# При решении этого шага считаем, что мы смотрим данные 1-го ноября 2019 года и что в нашей организации принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14

# %% [markdown]
# Отметим, что при расчёте окупаемости рекламы необходимо учитывать профили только тех пользователей, который были привлечены не с органического источника

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profile.query('channel != "organic"'), orders, observation_date, horizon_days)

# %% [markdown]
# Визуализируем LTV и ROI

# %%
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По графикам можно сделать такие выводы:
#
# - Реклама не окупается. ROI в конце недели — чуть выше 80%.
# - CAC увеличивается с течением времени
# - На LTV влияет сезонный фактор, но и этот показатель достаточно стабилен. Значит, дело не в ухудшении качества пользователей.

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по устройствам

# %% [markdown]
# Для того, чтобы разобраться в причинах, рассмотрим каждую характеристику профиля по отдельности.
#
# Начнём с разбивки по устройствам

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profile.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions=dimensions)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По графикам можно сделать следующие выводы:
#
# - Из всех устройств, окупается только лишь PC, ROI в конце двух недель примерно 110%. Причиной этому может служить относительно низкие затраты на привлечение пользователей
# - Для всех устройств CAC увеличивается с течением времени
# - LVT на всех устройствах достаточно стабилен

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по странам

# %% [markdown]
# Рассмотрим данные в разрезе регионов

# %%
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profile.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions=dimensions)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По графикам можно сделать следующие выводы:
#
# - Кроме США, все рассматриваемые регионы окупаются в конце двух недель со значением ROI около 115%. Причиной того, что пользователи из США не окупаются может быть то, что стоимость на их привлечение оносительно остальных стран сильно больше
# - Для США на протяжении всего времени CAC увеличивался, для других стран в январе, видимо, было принято решение о снижении стоимости привлечения пользователей
# - На LTV влияет сезонный фактор, но и этот показатель достаточно стабилен. Значит, дело не в ухудшении качества пользователей.

# %% [markdown]
# Дополнительно изучим окупаемость рекламы в США отдельно

# %%
dimensions = ['region', 'channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profile.query('region == "United States" and channel != "organic"'), orders, observation_date, horizon_days, dimensions=dimensions)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По графику ROI можем заметить, что на окупаемость пользователей из США сильно влияет канал привлечения, так:
#
# - Реклама на площадках `Yrabbit`, `MediaTornado`, `RocketSuperAds` окупается хорошо, в среднем на уровне 2.3, на площадках `TipTop` и `FaceBoom` окупаемость ниже 1
# - Объясняется это высокими значениями CAC для площадок `TipTop` и `FaceBoom`

# %% [markdown]
# Проверим гипотезу о том, что причиной общей низкой окупаемости пользователей США является тот факт, что большинство клиентов были привлечены с рекламных площадок TipTop и FaceBoom

# %%
profile.query('region == "United States" and channel != "organic"').groupby('channel').agg({'user_id' : 'nunique'}). \
sort_values(by = 'user_id', ascending=False)
# Out:
#                 user_id
# channel
# FaceBoom          29144
# TipTop            19561
# RocketSuperAds     4448
# MediaTornado       4364
# YRabbit            4312

# %% [markdown]
# Гипотеза подтвердилась: примерно 80% пользователей из США были привлечены из каналов TipTop и FaceBoom

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по рекламным каналам

# %% [markdown]
# Теперь проверим источники привлечения

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profile.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions=dimensions)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По графикам можно сделать следующие выводы:
#
# - К концу 2-ух недель окупаются почти все источники привлечения пользователей, кроме `TipTop`, `FaceBoom`, `AdNonSense`. Причиной низкой окупаемости площадки `TipTop` можно назвать постоянно возрастающие траты на привлечение пользователей (CAC)
# - На LTV опять же влияет сезонный фактор, этот показатель достаточно стабилен. Можно сказать, что пользователи, которые пришли из источника `IambdaMediaAds` обладают самым высоким показателем LTV

# %% [markdown]
# ### Посчитаем и визализируем конверсию в разных разрезах

# %% [markdown]
# Посчитаем и визуализируем конверсию в разбивке по источникам, вызвав функции get_conversion() и plot_conversion(). В данном случае можем не исключать органческих пользователей, так как в общем это не повлияет на качесто анализа, но для понимания зависимостей будет полезно знать - насколько хорошо конвертируются люди, приходящие из органического источника

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profile, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Судя по графикам, пользователи из источника `FaceBoom` конвертируются лучше, чем остальные

# %% [markdown]
# Рассмотрим конверсию в разрезе используемых устройств

# %%
dimensions = ['device']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profile, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Можно отметить, что пользователи PC конвертируются примерно в два раза хуже чем пользователи остальных платформ

# %% [markdown]
# Построим кривую и динамику конверсии в разрезе стран

# %%
dimensions = ['region']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profile, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Можем выделить явного лидера по показателю конверсии - США. Скорее всего это так же связанно с большими затратами на привлечение пользователей. Не забываем, что один из главных показателей качества бизнеса ROI у пользователей из США составляет 70%, соответсвенно инвестиции не окупаются

# %% [markdown]
# ### Посчитаем и визализируем удержание пользователей в разных разрезах

# %% [markdown]
# Полезно так же будет посмотреть на показатели удержания пользователя в разных разрезах.
#
# Начнём с разбивки по странам

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profile, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Удержание платящих пользователей из США заметно ниже относительно других стран. Удержание неплатящих у всех стран находится примерно на одном уровне

# %% [markdown]
# Рассмотрим коэффициент удержания относительно устройств пользователей

# %%
dimensions = ['device']
retention_raw, retention_grouped, retention_history = get_retention(
    profile, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Можем отметить, что удержание пользователей PC чуть выше остальных устройств.

# %% [markdown]
# Рассмотрим коэффициент удержания в разрезе источников привлечения

# %%
dimensions = ['channel']
retention_raw, retention_grouped, retention_history = get_retention(
    profile, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Небходимо отметить, что удержание пользователей из источников AdNonSense и FaceBoom к концу второй недели близко к нулю. Возможно, стоить предпринять меры по увеличению лояльности аудитории из этих источников, например внедрить использование пуш-уведомлений, e-mail рассылок и т.д.

# %% [markdown]
# ### Вывод

# %% [markdown]
# По результатам исследования окупаемости инвестиций сделаны следующие выводы:
#
# - Реклама не окупается. ROI в конце недели — чуть выше 80%.
# - CAC увеличивается с течением времени
# - На LTV влияет сезонный фактор, но и этот показатель достаточно стабилен. Значит, дело не в ухудшении качества пользователей.
# - Кроме США, все рассматриваемые регионы окупаются в конце двух недель со значением ROI около 115%. Причиной того, что пользователи из США не окупаются может быть то, что стоимость на их привлечение оносительно остальных стран сильно больше
# - Для США на протяжении всего времени CAC увеличивался, для других стран в январе, видимо, было принято решение о снижении стоимости привлечения пользователей
# - Для США отдельно были изучены каналы привлечения и выявлены причины низкой окупаемости, связанные с высокими значениям CAC для рекламных площадок `TipTop` и `FaceBoom`
# - Примерно 80% пользователей из США были привлечены из каналов TipTop и FaceBoom, что является причиной общей неокупаемости инвестиций в маркетинг для этого региона
# - К концу 2-ух недель окупаются почти все источники привлечения пользователей, кроме `TipTop`, `FaceBoom`, `AdNonSense`. Причиной низкой окупаемости площадки `TipTop` можно назвать постоянно возрастающие траты на привлечение пользователей (CAC)
# - На LTV опять же влияет сезонный фактор, этот показатель достаточно стабилен. Можно сказать, что пользователи, которые пришли из источника `IambdaMediaAds` обладают самым высоким показателем LTV
# - Судя по графикам, пользователи из источника `FaceBoom` конвертируются лучше, чем остальные
# - Так же необходимо отметить, что удержание пользователей из источников AdNonSense и FaceBoom к концу второй недели близко к нулю

# %% [markdown]
# ## Вывод
#
# Возможные пути решения неэффективности привлечения пользователей:
#
# - Снижание расходов на привлечение пользователей в США, для уменьшения CAC. Величина CAC на конец октября 2019 года соствавляет около 170%. Для достижения минимальной окупаемости значение CAC должно находиться на уровне не больше 100%. Достичь это значение можно путём уменьшение затрат на привлечение пользователей из каналов TipTop и FaceBoom
# - То же самое касается рекламного источника TipTop, LTV равен 148%, а CAC на уровне 350%. Соответсвенно для оптимизации метрики ROI необходимо пересмотреть величину вложений в привлечение пользователей из этого канала, так что бы CAC был меньше 148%
# - Так же стоит обратить внимание на удержание пользователей из источников AdNonSense и FaceBoom.  Возможно, стоит предпринять меры по увеличению лояльности аудитории из этих источников, например внедрить использование пуш-уведомлений, e-mail рассылок и т.д.
